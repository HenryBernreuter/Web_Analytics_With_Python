# %% [markdown]
# Media Analytics
# Spring 2019
# Project 3
# Henry Bernreuter

# %% [markdown]
# 1. (5 points)
#
# Install and/or load both "rtweet" and "twitteR" packages. For some questions, it may be easier to use "rtweet", for others it may be easier to use "twitteR".
#
# Establish secure connection with Twitter API. You should have learned how to do this in project 2.

# %%
import twitter

ACCESS_TOKEN = '1093922571106566145-BGG1JBUHX70Os2Kpla59P1mbOHfRko'
ACCESS_SECRET = 'Zjb4AN8jgCNJGuoYnkboVhYK7hMz7PVS9JniTSxhapaUE'
CONSUMER_KEY = 'eRIGzvLE9y39TPjJbsAFkxyqM'
CONSUMER_SECRET = 'cr8XJe33EcjcPoLdLtclzciwW6uXK3bOkGIcslMb6kyi8xYaJf'

api = twitter.Api(consumer_key='eRIGzvLE9y39TPjJbsAFkxyqM',
  consumer_secret='cr8XJe33EcjcPoLdLtclzciwW6uXK3bOkGIcslMb6kyi8xYaJf',
  access_token_key='1093922571106566145-BGG1JBUHX70Os2Kpla59P1mbOHfRko',
  access_token_secret='Zjb4AN8jgCNJGuoYnkboVhYK7hMz7PVS9JniTSxhapaUE')

print(api.VerifyCredentials())
# Out:
# {"created_at": "Fri Feb 08 17:20:39 +0000 2019", "default_profile": true, "friends_count": 8, "id": 1093922571106566145, "id_str": "1093922571106566145", "lang": "en", "name": "BurnzAnalytics", "profile_background_color": "F5F8FA", "profile_image_url": "http://pbs.twimg.com/profile_images/1093922700706414595/PuFjLQCd_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1093922700706414595/PuFjLQCd_normal.jpg", "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "screen_name": "AnalyticsBurnz"}

# %% [markdown]
# 2. (15 points)
#
# @GSUArtSci is the TWitter account of GSU College of Arts and Sciences.
# Get the description of this account.
# How many followers does @GSUArtSci have? Display a list of 10 followers.
# How many friends does @GSUArtSci have? Display a list of 10 friends.

# %%
import tweepy
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
CONSUMER_KEY = 'eRIGzvLE9y39TPjJbsAFkxyqM'
CONSUMER_SECRET = 'cr8XJe33EcjcPoLdLtclzciwW6uXK3bOkGIcslMb6kyi8xYaJf'
ACCESS_KEY = '1093922571106566145-BGG1JBUHX70Os2Kpla59P1mbOHfRko'
ACCESS_SECRET = 'Zjb4AN8jgCNJGuoYnkboVhYK7hMz7PVS9JniTSxhapaUE'
auth = OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
api = tweepy.API(auth)
auth.set_access_token(ACCESS_KEY, ACCESS_SECRET)

user = api.get_user(screen_name = 'GSUArtSci')
api = tweepy.API(auth)
test = api.lookup_users(user_ids=['47933604'])
friends = api.friends_ids(count = 20)
followers = user.followers_ids(count = 20)

print ("GSUArtSci's description is \n " + user.description)
print (user.followers_count)
print (user.friends_count)
for friend in user.friends():
   print (friend.id)

print (followers)
# Out:
# GSUArtSci's description is
#  The College of Arts and Sciences at Georgia State University
# 3191
# 434
# 2291254308
# 784304
# 1052203141964451841
# 3448941435
# 4595054353
# 192321572
# 15649433
# 570305463
# 4113012441
# 407947675
# 940340998739292160
# 948701448849813504
# 1044960152900849665
# 903704180
# 740691498602246144
# 709782739
# 1323603420
# 2848562901
# 15492359
# 743060037682221056
# [1086734889012072448, 267921024, 1080574167077007365, 2450472625, 2713636520, 1104093411265728514, 3043982998, 488422541, 366371801, 3273691388, 3315370524, 990309713899327491, 1106379281775636480, 1323256800, 950100567841542145, 796494092427464708, 1104884905803243521, 223702855, 18438022, 35595347]

# %% [markdown]
# 3.Use "igraph" to draw a social network graph of @GSUArtSci, showing 10 followers and 10 friends. Each follower should have an arrow pointing to @GSUArtSci, while each friend should have an arrow pointing from @GSUArtSci.
#
# Professor: As far as my reasearch can find igraph in no longer supported by Pytho3 the only one that I could find colase was jgraph.

# %%
import jgraph
graph = {
    'nodes': {
        'GSUArtSci': {'color': 0x2566ce, 'size': 3.10},
        '2291254308': {'color': 0xefec17, 'size': 1},
        '2425275252': {'color': 0xefec17, 'size': 1},
        '3788954511': {'color': 0xefec17, 'size': 1},
        '4113012441': {'color': 0xefec17, 'size': 1},
        '570305463': {'color': 0xefec17, 'size': 1},
        '192321572': {'color': 0xefec17, 'size': 1},
        '903704180': {'color': 0xefec17, 'size': 1},
        '1801': {'color': 0xefec17, 'size': 1},
        '940340998739292160': {'color': 0xefec17, 'size': 1},
        '1044960152900849665': {'color': 0xef17c8, 'size': 1},
        '1106379281775636480': {'color': 0xef17c8, 'size': 1},
        '1104': {'color': 0xef17c8, 'size': 1},
        '1323256800': {'color': 0xef17c8, 'size': 1},
        '3043982998': {'color': 0xef17c8, 'size': 1},
        '15649433': {'color': 0xef17c8, 'size': 1},
        '2848562901': {'color': 0xef17c8, 'size': 1},
        '796494092427464708': {'color': 0xef17c8, 'size': 1},
        '18438022': {'color': 0xef17c8, 'size': 1},
        '990309713899327491': {'color': 0xef17c8, 'size': 1},
        '3315370524': {'color': 0xef17c8, 'size': 1},
        '407947675': {'color': 0xef17c8, 'size': 1},
    },
    'edges': [
        {'source': '2291254308', 'target': 'GSUArtSci'},
        {'source': '2425275252', 'target': 'GSUArtSci'},
        {'source': '3788954511', 'target': 'GSUArtSci'},
        {'source': '4113012441', 'target': 'GSUArtSci'},
        {'source': '570305463', 'target': 'GSUArtSci'},
        {'source': '192321572', 'target': 'GSUArtSci'},
        {'source': '903704180', 'target': 'GSUArtSci'},
        {'source': '1801', 'target': 'GSUArtSci'},
        {'source': '940340998739292160', 'target': 'GSUArtSci'},
        {'source': '1044960152900849665', 'target': 'GSUArtSci'},
        {'source': 'GSUArtSci', 'target': '1106379281775636480'},
        {'source': 'GSUArtSci', 'target': '1104'},
        {'source': 'GSUArtSci', 'target': '1323256800'},
        {'source': 'GSUArtSci', 'target': '3043982998'},
        {'source': 'GSUArtSci', 'target': '15649433'},
        {'source': 'GSUArtSci', 'target': '2848562901'},
        {'source': 'GSUArtSci', 'target': '796494092427464708'},
        {'source': 'GSUArtSci', 'target': '18438022'},
        {'source': 'GSUArtSci', 'target': '990309713899327491'},
        {'source': 'GSUArtSci', 'target': '3315370524'},
        {'source': 'GSUArtSci', 'target': '407947675'}
    ]
}

jgraph.draw(graph)
# Out:
# <div id="graph-a9fd6b7a-51aa-4bc4-b6c9-458c50d143ae"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                              paths: {jgraph: ['nbextensions/jgraph.min', 'https://rawgit.com/patrickfuller/jgraph/master/js/build/jgraph.min']}});
#            require(['jgraph'], function () {
#                var $d = $('#graph-a9fd6b7a-51aa-4bc4-b6c9-458c50d143ae');
#                $d.width(600); $d.height(400);
#                $d.jgraph = jQuery.extend({}, jgraph);
#                $d.jgraph.create($d, {nodeSize: 2.000000,
#                                      edgeSize: 0.250000,
#                                      defaultNodeColor: '0x5bc0de',
#                                      defaultEdgeColor: '0xaaaaaa',
#                                      shader: 'basic',
#                                      z: 100,
#                                      runOptimization: true,
# ...

# %% [markdown]
# 4. Find out what is currently trending in Atlanta on Twitter.
# Retrieve the top trending hashtag and display 100 tweets of that hashtag.
# Display the user screen names of the 100 tweets you retrieved.

# %%
import tweepy
import pandas as pd
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
CONSUMER_KEY = 'eRIGzvLE9y39TPjJbsAFkxyqM'
CONSUMER_SECRET = 'cr8XJe33EcjcPoLdLtclzciwW6uXK3bOkGIcslMb6kyi8xYaJf'
ACCESS_KEY = '1093922571106566145-BGG1JBUHX70Os2Kpla59P1mbOHfRko'
ACCESS_SECRET = 'Zjb4AN8jgCNJGuoYnkboVhYK7hMz7PVS9JniTSxhapaUE'
auth = OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
api = tweepy.API(auth)
auth.set_access_token(ACCESS_KEY, ACCESS_SECRET)
df = pd.DataFrame(columns=['text', 'source', 'url'])
msgs = []
msg =[]

for tweet in tweepy.Cursor(api.search, q='#atlanta', rpp=100).items(100):
    msg = [tweet.id_str]                     
    msgs.append(msg)

df = pd.DataFrame(msgs)
print(df)
# Out:
#                       0
# 0   1112776691234029572
# 1   1112776444122263563
# 2   1112776045374201858
# 3   1112776042228453376
# 4   1112776020158046208
# 5   1112775675872600064
# 6   1112775146564091905
# 7   1112774954175643654
# 8   1112774844708319233
# 9   1112774034444439552
# 10  1112773849727340544
# 11  1112773829082775552
# 12  1112773705879470081
# 13  1112773559359889409
# 14  1112773281449426944
# 15  1112773185756389376
# 16  1112772975135244289
# 17  1112772927513128965
# 18  1112772891295272965
# 19  1112772794390077440
# 20  1112772633156902913
# 21  1112772476419928064
# 22  1112772366948601857
# 23  1112772111121018882
# 24  1112772059657068546
# 25  1112772032624640000
# 26  1112772024240390145
# 27  1112771916853624832
# 28  1112771858066104320
# 29  1112771676742316032
# ..                  ...
# 70  1112766452464082944
# 71  1112766261962903554
# 72  1112766188185182208
# 73  1112765759766306817
# 74  1112764955323973633
# 75  1112764784183836673
# ...

# %% [markdown]
# 5.Install and load "ggmap". Register a Google Maps API key and register this API key with ggmap.
# Try to retrieve Twitter data (using keywords of your choice) that contains geolocation information.
# Plot the Tweet locations on a map.
# api key = AIzaSyAxOxEYz991X-NXtxqs3bxiAdi7c2KlSvw

# %%
import gmaps
import pandas as pd
gmaps.configure(api_key='AIzaSyAxOxEYz991X-NXtxqs3bxiAdi7c2KlSvw')
houses = "C:\\Users\\new user\\Desktop\\CMIS 4070\\houses.csv"
df = pd.read_csv(houses)
location_columns = df[['latitude', 'longitude']]
location_tuples = [tuple(x) for x in location_columns.values]
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(location_tuples))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# 6. Retrieve 200 Tweets that contains #CaptainMarvelreview, excluding retweets.
# Clean up the tweets by removing hashtags, URLs, RTs, etc.
# Use "syuzhet" package for sentiment analysis.
# Get the sentiment scores of the tweets using three methods: "syuzhet", "bing", and "afinn".
# What is the mean "syuzhet" sentiment score?
# What is the mean "bing" sentiment score?
# Use "ggplot2" to draw a line chart with three lines, each showing the "syuzhet", "bing", and "afinn" sentiment scores for the 200 tweets.
# Based on your analysis? Are the reviews of the movie Captain Marvel generally positive, negative, or neutral?

# %%
import tweepy
import pandas as pd
from textblob import TextBlob
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
CONSUMER_KEY = 'eRIGzvLE9y39TPjJbsAFkxyqM'
CONSUMER_SECRET = 'cr8XJe33EcjcPoLdLtclzciwW6uXK3bOkGIcslMb6kyi8xYaJf'
ACCESS_KEY = '1093922571106566145-BGG1JBUHX70Os2Kpla59P1mbOHfRko'
ACCESS_SECRET = 'Zjb4AN8jgCNJGuoYnkboVhYK7hMz7PVS9JniTSxhapaUE'
auth = OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
api = tweepy.API(auth)
auth.set_access_token(ACCESS_KEY, ACCESS_SECRET)
df = pd.DataFrame(columns=['text', 'source', 'url'])
msgs = []
msg =[]

public_tweets = api.search('#CaptainMarvelreview')

for tweet in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    if analysis.sentiment[0]>0:
        print ('Positive')
    else:
        print ('Negative')
    print("")
# Out:
# RT @Moustache_News: Our review of @captainmarvel is online now #CaptainMarvel #CaptainMarvelReview #MarvelStudios #MarvelCinematicUniverse…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Negative
#
# RT @FantacCisse: #CaptainMarvelPremiere was so incredibly good! I am so lucky I got to see it tonight! #legrandrex #womenexcellence #thanos…
# Sentiment(polarity=0.6458333333333333, subjectivity=0.7166666666666668)
# Positive
#
# Go check out my latest review for Captain Marvel!
# LINK: https://t.co/Y44fhYSc39
# _______
# #CaptainMarvel… https://t.co/uDmXgdKndV
# Sentiment(polarity=0.625, subjectivity=0.9)
# Positive
#
# Yes sir the #avengerendgame #posters look dope, watch me give a #breakdown on them while giving you my… https://t.co/gcH1C5OSos
# Sentiment(polarity=0.0, subjectivity=0.0)
# Negative
#
# RT @IndiaCinepolis: Are you watching #CaptainMarvel this weekend?
# #Cinepolis #CinepolisIndia #CaptainMarvelreview #CineReviews #CarolDanver…
# Sentiment(polarity=0.0, subjectivity=0.0)
# ...
